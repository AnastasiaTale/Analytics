# %%
import requests
import pandas as pd

# %%
number_of_pages = 100
#number_of_ads = number_of_pages * per_page

# %%
job_title = ["'Data Analyst' and 'data scientist'"]
for job in job_title:
	data=[]
	for i in range(number_of_pages):
	    url = 'https://api.hh.ru/vacancies'
	    par = {'text': job, 'area':'113','per_page':'10', 'page':i}
	    r = requests.get(url, params=par)
	    e=r.json()
	    data.append(e)
	    vacancy_details = data[0]['items'][0].keys()
	    df = pd.DataFrame(columns= list(vacancy_details))
	    ind = 0
	    for i in range(len(data)):
	    	for j in range(len(data[i]['items'])):
	    		df.loc[ind] = data[i]['items'][j]
	    		ind+=1
csv_name = job+".csv"
df.to_csv(csv_name)

# %%
df = pd.read_csv('data scientist.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        id  premium                                        name  \
# 0           0  49423067    False                              Data Scientist
# 1           1  54786210    False            Data scientist / Product analyst
# 2           2  54970300    False            Аналитик данных / Data scientist
# 3           3  55185255    False             Data Analyst ( Data Scientist )
# 4           4  55221077    False  Data Analyst / Data Scientist (SQL/Oracle)
#
#   department  has_test  response_letter_required  \
# 0        NaN     False                     False
# 1        NaN     False                     False
# 2        NaN     False                     False
# 3        NaN     False                     False
# 4        NaN     False                     False
#
#                                                 area  \
# 0  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  {'id': '77', 'name': 'Рязань', 'url': 'https:/...
# 3  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4  {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                               salary  \
# 0  {'from': None, 'to': 380000, 'currency': 'RUR'...
# 1  {'from': 200000, 'to': 250000, 'currency': 'RU...
# 2  {'from': 130000, 'to': 180000, 'currency': 'RU...
# 3                                                NaN
# 4                                                NaN
#
#                                  type  ...                   alternate_url  \
# 0  {'id': 'open', 'name': 'Открытая'}  ...  https://hh.ru/vacancy/49423067
# 1  {'id': 'open', 'name': 'Открытая'}  ...  https://hh.ru/vacancy/54786210
# 2  {'id': 'open', 'name': 'Открытая'}  ...  https://hh.ru/vacancy/54970300
# 3  {'id': 'open', 'name': 'Открытая'}  ...  https://hh.ru/vacancy/55185255
# 4  {'id': 'open', 'name': 'Открытая'}  ...  https://hh.ru/vacancy/55221077
#
#    relations                                           employer  \
# 0         []  {'id': '2324020', 'name': 'Точка', 'url': 'htt...
# 1         []  {'id': '2652595', 'name': 'Bip.ru', 'url': 'ht...
# 2         []  {'id': '1791985', 'name': 'MNOGOGAMES', 'url':...
# 3         []  {'id': '4448058', 'name': 'МКК КапиталЪ-НТ', '...
# 4         []  {'id': '1439', 'name': 'ВСК, САО', 'url': 'htt...
#
#                                              snippet contacts  \
# 0  {'requirement': 'Есть опыт работы с методами м...      NaN
# 1  {'requirement': 'Опыт работы <highlighttext>ан...      NaN
# 2  {'requirement': 'Знание математических алгорит...      NaN
# 3  {'requirement': 'Высшее образование. Опыт рабо...      NaN
# 4  {'requirement': 'Высшее образование (техническ...      NaN
#
#                                        schedule working_days  \
# 0      {'id': 'fullDay', 'name': 'Полный день'}           []
# 1  {'id': 'remote', 'name': 'Удаленная работа'}           []
# 2  {'id': 'remote', 'name': 'Удаленная работа'}           []
# 3      {'id': 'fullDay', 'name': 'Полный день'}           []
# 4      {'id': 'fullDay', 'name': 'Полный день'}           []
#
#   working_time_intervals working_time_modes accept_temporary
# 0                     []                 []            False
# 1                     []                 []            False
# 2                     []                 []            False
# 3                     []                 []            False
# 4                     []                 []            False
#
# [5 rows x 29 columns]

# %%
df.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
df.set_index('index', inplace=True)

# %%
df.head()
# Out:
#              id  premium                                        name  \
# index
# 0      49423067    False                              Data Scientist
# 1      54786210    False            Data scientist / Product analyst
# 2      54970300    False            Аналитик данных / Data scientist
# 3      55185255    False             Data Analyst ( Data Scientist )
# 4      55221077    False  Data Analyst / Data Scientist (SQL/Oracle)
#
#       department  has_test  response_letter_required  \
# index
# 0            NaN     False                     False
# 1            NaN     False                     False
# 2            NaN     False                     False
# 3            NaN     False                     False
# 4            NaN     False                     False
#
#                                                     area  \
# index
# 0      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 1      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2      {'id': '77', 'name': 'Рязань', 'url': 'https:/...
# 3      {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4      {'id': '1', 'name': 'Москва', 'url': 'https://...
#
#                                                   salary  \
# index
# 0      {'from': None, 'to': 380000, 'currency': 'RUR'...
# 1      {'from': 200000, 'to': 250000, 'currency': 'RU...
# 2      {'from': 130000, 'to': 180000, 'currency': 'RU...
# 3                                                    NaN
# 4                                                    NaN
#
#                                      type  \
# index
# 0      {'id': 'open', 'name': 'Открытая'}
# 1      {'id': 'open', 'name': 'Открытая'}
# 2      {'id': 'open', 'name': 'Открытая'}
# 3      {'id': 'open', 'name': 'Открытая'}
# 4      {'id': 'open', 'name': 'Открытая'}
#
#                                                  address  ...  \
# index                                                     ...
# 0                                                    NaN  ...
# 1      {'city': 'Москва', 'street': 'Нижняя Красносел...  ...
# 2      {'city': 'Рязань', 'street': 'Лесопарковая ули...  ...
# 3                                                    NaN  ...
# 4      {'city': None, 'street': None, 'building': Non...  ...
#
#                         alternate_url  relations  \
# index
# 0      https://hh.ru/vacancy/49423067         []
# 1      https://hh.ru/vacancy/54786210         []
# 2      https://hh.ru/vacancy/54970300         []
# 3      https://hh.ru/vacancy/55185255         []
# 4      https://hh.ru/vacancy/55221077         []
#
#                                                 employer  \
# index
# 0      {'id': '2324020', 'name': 'Точка', 'url': 'htt...
# 1      {'id': '2652595', 'name': 'Bip.ru', 'url': 'ht...
# 2      {'id': '1791985', 'name': 'MNOGOGAMES', 'url':...
# 3      {'id': '4448058', 'name': 'МКК КапиталЪ-НТ', '...
# 4      {'id': '1439', 'name': 'ВСК, САО', 'url': 'htt...
#
#                                                  snippet  contacts  \
# index
# 0      {'requirement': 'Есть опыт работы с методами м...       NaN
# 1      {'requirement': 'Опыт работы <highlighttext>ан...       NaN
# 2      {'requirement': 'Знание математических алгорит...       NaN
# 3      {'requirement': 'Высшее образование. Опыт рабо...       NaN
# 4      {'requirement': 'Высшее образование (техническ...       NaN
#
#                                            schedule working_days  \
# index
# 0          {'id': 'fullDay', 'name': 'Полный день'}           []
# 1      {'id': 'remote', 'name': 'Удаленная работа'}           []
# 2      {'id': 'remote', 'name': 'Удаленная работа'}           []
# 3          {'id': 'fullDay', 'name': 'Полный день'}           []
# 4          {'id': 'fullDay', 'name': 'Полный день'}           []
#
#       working_time_intervals working_time_modes accept_temporary
# index
# 0                         []                 []            False
# 1                         []                 []            False
# 2                         []                 []            False
# 3                         []                 []            False
# 4                         []                 []            False
#
# [5 rows x 28 columns]

# %%
df.info() #Общая информация о датасете
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 169
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        170 non-null    int64
#  1   premium                   170 non-null    bool
#  2   name                      170 non-null    object
#  3   department                40 non-null     object
#  4   has_test                  170 non-null    bool
#  5   response_letter_required  170 non-null    bool
#  6   area                      170 non-null    object
#  7   salary                    22 non-null     object
#  8   type                      170 non-null    object
#  9   address                   73 non-null     object
#  10  response_url              0 non-null      float64
#  11  sort_point_distance       0 non-null      float64
#  12  published_at              170 non-null    object
#  13  created_at                170 non-null    object
#  14  archived                  170 non-null    bool
#  15  apply_alternate_url       170 non-null    object
#  16  insider_interview         6 non-null      object
#  17  url                       170 non-null    object
#  18  alternate_url             170 non-null    object
#  19  relations                 170 non-null    object
#  20  employer                  170 non-null    object
#  21  snippet                   170 non-null    object
#  22  contacts                  0 non-null      float64
#  23  schedule                  170 non-null    object
#  24  working_days              170 non-null    object
#  25  working_time_intervals    170 non-null    object
#  26  working_time_modes        170 non-null    object
#  27  accept_temporary          170 non-null    bool
# dtypes: bool(5), float64(3), int64(1), object(19)
# memory usage: 32.7+ KB

# %%
import ast # run code from string for example ast.literal_eval("1+1") 

salaries = df.salary.dropna() # remove all NA's from dataframe
currencies = [ast.literal_eval(salaries.iloc[i])['currency'] for i in range(len(salaries))]
curr = set(currencies) #{'EUR', 'RUR', 'USD'}

#divide dataframe salararies by currency
rur = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='RUR']
eur = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='EUR']
usd = [ast.literal_eval(salaries.iloc[i]) for i in range(len(salaries)) if ast.literal_eval(salaries.iloc[i])['currency']=='USD']

# %%
fr = [x['from'] for x in rur] # lower range of salary
fr = list(filter(lambda x: x is not None, fr)) # remove NA's from lower range [0, 100, 200,...]

to = [x['to'] for x in rur] #upper range of salary
to = list(filter(lambda x: x is not None, to)) #remove NA's from upper range [100, 200, 300,...]

import numpy as np
salary_range = list(zip(fr, to)) # concatenate upper and lower range  [(0,100), (100, 200), (200, 300)...]
av = map(np.mean, salary_range) # convert [(0,100), (100, 200), (200, 300)...] to [50, 150, 250,...]
av = round(np.mean(list(av)),1) # average value from [50, 150, 250,...]

print("average salary as Data Scientist ", av, "rubles")
# Out:
# average salary as Data Scientist  214583.3 rubles

# %%
from collections import Counter

vacancy_names = df.name # change here to change source of data/words etc
cloud = Counter(vacancy_names)
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)
cloud = ''
for x in list(vacancy_names):
    cloud+=x+' '
wordcloud = WordCloud(width = 800, height = 800, 

                stopwords = stopwords, 
                min_font_size = 8,background_color='white'
                     ).generate(cloud)

import matplotlib.pylab as plt
plt.figure(figsize = (16, 16)) 
plt.imshow(wordcloud)
plt.savefig('vacancy_cloud.png')

# %%
from matplotlib import pyplot as plt

# %%
df.location.unique()
